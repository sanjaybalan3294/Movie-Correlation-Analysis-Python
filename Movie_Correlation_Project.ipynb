# %% [markdown]
# # Movie Industry Correlation Analysis
#
# ## Project Overview
#
# This project analyzes movie industry data to identify the factors most strongly associated with gross earnings.
#
# ### Analysis Performed
#
# - Data Cleaning
# - Missing Value Handling
# - Duplicate Detection
# - Exploratory Data Analysis (EDA)
# - Budget vs Gross Earnings Analysis
# - Correlation Analysis
# - Correlation Heatmap
#
# ### Tools & Libraries
#
# - Python
# - Jupyter Notebook
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Load Dataset

# %%
df = pd.read_csv('C:/Users/SANJAY/Downloads/movies.csv/movies.csv')

# %% [markdown]
# ## 3. Data Exploration
#
# In this section, we explore the structure, data types, dimensions, and missing values in the movie dataset.

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.dtypes
# Out:
# name            str
# rating          str
# genre           str
# year          int64
# released        str
# score       float64
# votes       float64
# director        str
# writer          str
# star            str
# country         str
# budget      float64
# gross       float64
# company         str
# runtime     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df.shape
# Out:
# (7668, 15)

# %% [markdown]
# ## 4. Data Cleaning
#
# In this section, missing values are handled, numerical columns are converted to appropriate data types, and duplicate records are checked.

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
df['gross'] = df['gross'].astype('int64')

# %%
df['budget'] = df['budget'].astype('int64')

# %%
df.dtypes
# Out:
# name            str
# rating          str
# genre           str
# year          int64
# released        str
# score       float64
# votes       float64
# director        str
# writer          str
# star            str
# country         str
# budget        int64
# gross         int64
# company         str
# runtime     float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['budget'] = df['budget'].astype('int64')

# %%
df.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)
#
# In this section, we visualize the relationship between movie budget and gross earnings to identify trends and patterns in the data.

# %%
plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross ')

plt.xlabel('Budget for Film')

plt.ylabel('Gross Earnings')

plt.show()

# %%
sns.regplot(
    x='budget',
    y='gross',
    data=df,
    scatter_kws={'alpha': 0.5},
    line_kws={'color': 'red', 'linewidth': 2}
)

plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget for Film')
plt.ylabel('Gross Earnings')

plt.show()

# %% [markdown]
# ## 6. Correlation Analysis
#
# In this section, correlation analysis is performed to identify relationships between numerical movie features, particularly the factors associated with gross earnings.

# %%
df.corr(numeric_only=True)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
correlation_matrix = df.corr(numeric_only=True)

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')

plt.show()

# %%
df_numerized = df.copy()

# %%
for col_name in df_numerized.select_dtypes(include=['object', 'string']).columns:
    df_numerized[col_name] = df_numerized[col_name].astype('category').cat.codes

# %%
df_numerized.dtypes
# Out:
# name          int16
# rating         int8
# genre          int8
# year          int64
# released      int16
# score       float64
# votes       float64
# director      int16
# writer        int16
# star          int16
# country        int8
# budget        int64
# gross         int64
# company       int16
# runtime     float64
# dtype: object

# %%
correlation_matrix = df_numerized.corr()

correlation_matrix
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating   -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre     0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year      0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score     0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes     0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director  0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer    0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star     -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country  -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget    0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# gross     0.005639 -0.181906 -0.244101  0.274321  0.008501  0.222556
# ...

# %%
plt.figure(figsize=(12, 8))

sns.heatmap(
    correlation_matrix,
    annot=True
)

plt.title('Correlation Matrix for Movie Features')

plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name     name        1.000000
#          rating     -0.029234
#          genre       0.010996
#          year        0.025542
#          released   -0.006152
#                        ...
# runtime  country    -0.034477
#          budget      0.318695
#          gross       0.275796
#          company     0.037585
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre    budget    -0.368523
# budget   genre     -0.368523
# gross    genre     -0.244101
# genre    gross     -0.244101
# rating   budget    -0.203946
#                       ...
# budget   budget     1.000000
# country  country    1.000000
# gross    gross      1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %%
high_corr = sorted_pairs[
    (sorted_pairs > 0.5) &
    (sorted_pairs < 1)
]

high_corr
# Out:
# votes   gross     0.614751
# gross   votes     0.614751
# budget  gross     0.740247
# gross   budget    0.740247
# dtype: float64

# %% [markdown]
# # Conclusion
#
# ## Key Findings
#
# - **Budget and gross earnings have the strongest positive correlation (0.74)**, indicating that higher-budget movies tend to generate higher gross revenue.
#
# - **Votes and gross earnings have a moderately strong positive correlation (0.61)**, suggesting that movies with greater audience engagement tend to earn more.
#
# - **Budget showed the strongest association with gross earnings** among the numerical variables analyzed.
#
# - Other numerical variables such as score, runtime, and year showed comparatively weaker correlations with gross earnings.
#
# ## Final Insight
#
# The analysis suggests that **movie budget and audience engagement (votes) are the two variables most strongly associated with gross earnings** in this dataset.
#
# **Note:** Correlation shows an association between variables, but it does not prove causation.
